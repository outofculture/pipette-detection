# %% [markdown]
# Same model as 02, but training on more difficult data (d0.00-0.60)
#
#
# **Performance:**
# - excellent!
# - takes about 10k batches, performance still improving slowly at 20k
#
# ```
# Total params: 42,506,307
# Trainable params: 18,717,699
# Non-trainable params: 23,788,608
# ----------------------------------------------------------------
# Input size (MB): 1.83
# Forward/backward pass size (MB): 1373.79
# Params size (MB): 162.15
# Estimated Total Size (MB): 1537.77
# ```
#
# **Model:**
# ImageNet1k_v2
# - training resnet [-2][-2:] and [-1]
# - adaptive avg pooling layer
# - one dense layer with xyz output
#
# **Training:**
# - Batch size 96
# - MSE loss
# - Adam, learning rate 0.001

# %%
import numpy as np
from training_data import load_training_data
import matplotlib.pyplot as plt

# %%
save_path = "torch_models/03_increased_difficulty.pth"
training_data_path = "training_data"

# %%
training_data = load_training_data(training_data_path)
levels = list(training_data.levels.keys())

# keep just the first 4 levels
training_data.levels = {level: training_data.levels[level] for level in levels[:4]}
print(training_data.levels.keys())
# Out:
# dict_keys(['d0.00', 'd0.20', 'd0.40', 'd0.60'])

# %%
# Build a pytorch model consisting of:
# - a resnet101v2 pretrained on imagenet, excluding its final classification layer
#    (the final layer has output shape (batch_size, M, N, channels)
# - a max pooling layer that takes the maximum only over channels (output shape (batch_size, M, N))
# - a dense layer with 3 one-hot outputs (output shape (batch_size, 3, onehot_size))

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models

print("CUDA:", torch.cuda.is_available())

class PipetteDetector(nn.Module):
    def __init__(self):
        super(PipetteDetector, self).__init__()
        resnet101 = models.resnet101(weights=models.ResNet101_Weights.IMAGENET1K_V2)
        self.resnet = torch.nn.Sequential(*(list(resnet101.children())[:-2]))

        # freeze all parameters in the resnet
        for param in self.resnet.parameters():
            param.requires_grad = False
        
        # unfreeze the last block (10 layers)
        # for param in self.resnet[-1][-1].parameters():
        #     param.requires_grad = True

        # unfreeze thelast 6th-4rd blocks (30 layers) 
        for i in range(3):
            for param in self.resnet[-2][-i].parameters():
                param.requires_grad = True
        
        # unfreeze the last 3 blocks (30 layers)
        for param in self.resnet[-1].parameters():
            param.requires_grad = True
            
        # global average pooling 2d
        self.pooling = nn.AdaptiveAvgPool2d((1, 1))
        # self.pooling = nn.AdaptiveMaxPool2d((1, 1))

        # max pooling 2d
        # self.pooling = nn.MaxPool2d(kernel_size=2, stride=2)
        # self.pooling = nn.AvgPool2d(kernel_size=2, stride=2)

        # self.layers = torch.nn.Sequential(
        #     nn.LazyConv2d(4, kernel_size=3, stride=1, padding=1),
        #     nn.ReLU(),
        #     nn.LazyConv2d(8, kernel_size=7, stride=1, padding=3),
        #     nn.ReLU(),
        #     nn.LazyConv2d(16, kernel_size=15, stride=1, padding=7),
        #     nn.ReLU(),
        #     nn.LazyConv2d(16, kernel_size=15, stride=1, padding=7),
        #     nn.ReLU(),
        #     nn.LazyConv2d(16, kernel_size=15, stride=1, padding=7),
        #     nn.ReLU(),
        # )

        # If output size is currently (channels, height, width), add a convolutional layer with kernel size (height, 1) and output size (1, onehot_size)
        # output_shape = (13, 13)
        # self.x_conv = nn.LazyConv2d((onehot_size // output_shape[1]) + 1, kernel_size=(output_shape[0], 1))
        # self.y_conv = nn.LazyConv2d((onehot_size // output_shape[0]) + 1, kernel_size=(1, output_shape[1]))
        # self.z_conv = nn.LazyConv2d((onehot_size // output_shape[0]) + 1, kernel_size=(1, output_shape[1]))

        self.xyz_out = nn.LazyLinear(3)

    def forward(self, input):
        resnet_output = self.resnet(input)

        # x = self.x_conv(resnet_output)
        # y = self.y_conv(resnet_output)
        # # flatten x and y
        # x = x.reshape(x.size(0), -1)
        # y = y.reshape(y.size(0), -1)
        # # crop to onehot_size
        # x = x[:, :onehot_size]
        # y = y[:, :onehot_size]

        pooled = self.pooling(resnet_output)

        flat = pooled.reshape(pooled.size(0), -1)
        # flat = input.reshape(input.size(0), -1)
        # flat = resnet_output.reshape(resnet_output.size(0), -1)

        # output = self.layers(input)
        # flat = output.reshape(output.size(0), -1)
        xyz = self.xyz_out(flat)
        return xyz
    
# initialize a model just to see its structure
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# CUDA: True

# %%
from torchsummary import summary
test_model = PipetteDetector()
test_model.to(device);
# print(model)
summary(test_model, input_size=(3, 400, 400))

del test_model
torch.cuda.empty_cache()
# Out:
# /home/luke/pipette-detection/conda_env/lib/python3.12/site-packages/torch/nn/modules/lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 200, 200]           9,408
#        BatchNorm2d-2         [-1, 64, 200, 200]             128
#               ReLU-3         [-1, 64, 200, 200]               0
#          MaxPool2d-4         [-1, 64, 100, 100]               0
#             Conv2d-5         [-1, 64, 100, 100]           4,096
#        BatchNorm2d-6         [-1, 64, 100, 100]             128
#               ReLU-7         [-1, 64, 100, 100]               0
#             Conv2d-8         [-1, 64, 100, 100]          36,864
#        BatchNorm2d-9         [-1, 64, 100, 100]             128
#              ReLU-10         [-1, 64, 100, 100]               0
#            Conv2d-11        [-1, 256, 100, 100]          16,384
#       BatchNorm2d-12        [-1, 256, 100, 100]             512
#            Conv2d-13        [-1, 256, 100, 100]          16,384
#       BatchNorm2d-14        [-1, 256, 100, 100]             512
#              ReLU-15        [-1, 256, 100, 100]               0
#        Bottleneck-16        [-1, 256, 100, 100]               0
#            Conv2d-17         [-1, 64, 100, 100]          16,384
#       BatchNorm2d-18         [-1, 64, 100, 100]             128
#              ReLU-19         [-1, 64, 100, 100]               0
#            Conv2d-20         [-1, 64, 100, 100]          36,864
#       BatchNorm2d-21         [-1, 64, 100, 100]             128
#              ReLU-22         [-1, 64, 100, 100]               0
#            Conv2d-23        [-1, 256, 100, 100]          16,384
#       BatchNorm2d-24        [-1, 256, 100, 100]             512
#              ReLU-25        [-1, 256, 100, 100]               0
#        Bottleneck-26        [-1, 256, 100, 100]               0
#            Conv2d-27         [-1, 64, 100, 100]          16,384
#       BatchNorm2d-28         [-1, 64, 100, 100]             128
#              ReLU-29         [-1, 64, 100, 100]               0
#            Conv2d-30         [-1, 64, 100, 100]          36,864
#       BatchNorm2d-31         [-1, 64, 100, 100]             128
#              ReLU-32         [-1, 64, 100, 100]               0
#            Conv2d-33        [-1, 256, 100, 100]          16,384
#       BatchNorm2d-34        [-1, 256, 100, 100]             512
#              ReLU-35        [-1, 256, 100, 100]               0
#        Bottleneck-36        [-1, 256, 100, 100]               0
#            Conv2d-37        [-1, 128, 100, 100]          32,768
#       BatchNorm2d-38        [-1, 128, 100, 100]             256
#              ReLU-39        [-1, 128, 100, 100]               0
#            Conv2d-40          [-1, 128, 50, 50]         147,456
#       BatchNorm2d-41          [-1, 128, 50, 50]             256
#              ReLU-42          [-1, 128, 50, 50]               0
#            Conv2d-43          [-1, 512, 50, 50]          65,536
#       BatchNorm2d-44          [-1, 512, 50, 50]           1,024
#            Conv2d-45          [-1, 512, 50, 50]         131,072
#       BatchNorm2d-46          [-1, 512, 50, 50]           1,024
#              ReLU-47          [-1, 512, 50, 50]               0
#        Bottleneck-48          [-1, 512, 50, 50]               0
#            Conv2d-49          [-1, 128, 50, 50]          65,536
#       BatchNorm2d-50          [-1, 128, 50, 50]             256
#              ReLU-51          [-1, 128, 50, 50]               0
#            Conv2d-52          [-1, 128, 50, 50]         147,456
#       BatchNorm2d-53          [-1, 128, 50, 50]             256
#              ReLU-54          [-1, 128, 50, 50]               0
#            Conv2d-55          [-1, 512, 50, 50]          65,536
#       BatchNorm2d-56          [-1, 512, 50, 50]           1,024
#              ReLU-57          [-1, 512, 50, 50]               0
#        Bottleneck-58          [-1, 512, 50, 50]               0
#            Conv2d-59          [-1, 128, 50, 50]          65,536
#       BatchNorm2d-60          [-1, 128, 50, 50]             256
#              ReLU-61          [-1, 128, 50, 50]               0
#            Conv2d-62          [-1, 128, 50, 50]         147,456
#       BatchNorm2d-63          [-1, 128, 50, 50]             256
#              ReLU-64          [-1, 128, 50, 50]               0
#            Conv2d-65          [-1, 512, 50, 50]          65,536
#       BatchNorm2d-66          [-1, 512, 50, 50]           1,024
#              ReLU-67          [-1, 512, 50, 50]               0
#        Bottleneck-68          [-1, 512, 50, 50]               0
#            Conv2d-69          [-1, 128, 50, 50]          65,536
#       BatchNorm2d-70          [-1, 128, 50, 50]             256
#              ReLU-71          [-1, 128, 50, 50]               0
#            Conv2d-72          [-1, 128, 50, 50]         147,456
#       BatchNorm2d-73          [-1, 128, 50, 50]             256
#              ReLU-74          [-1, 128, 50, 50]               0
#            Conv2d-75          [-1, 512, 50, 50]          65,536
#       BatchNorm2d-76          [-1, 512, 50, 50]           1,024
#              ReLU-77          [-1, 512, 50, 50]               0
#        Bottleneck-78          [-1, 512, 50, 50]               0
#            Conv2d-79          [-1, 256, 50, 50]         131,072
#       BatchNorm2d-80          [-1, 256, 50, 50]             512
#              ReLU-81          [-1, 256, 50, 50]               0
#            Conv2d-82          [-1, 256, 25, 25]         589,824
#       BatchNorm2d-83          [-1, 256, 25, 25]             512
#              ReLU-84          [-1, 256, 25, 25]               0
#            Conv2d-85         [-1, 1024, 25, 25]         262,144
#       BatchNorm2d-86         [-1, 1024, 25, 25]           2,048
#            Conv2d-87         [-1, 1024, 25, 25]         524,288
#       BatchNorm2d-88         [-1, 1024, 25, 25]           2,048
#              ReLU-89         [-1, 1024, 25, 25]               0
#        Bottleneck-90         [-1, 1024, 25, 25]               0
#            Conv2d-91          [-1, 256, 25, 25]         262,144
#       BatchNorm2d-92          [-1, 256, 25, 25]             512
#              ReLU-93          [-1, 256, 25, 25]               0
#            Conv2d-94          [-1, 256, 25, 25]         589,824
#       BatchNorm2d-95          [-1, 256, 25, 25]             512
#              ReLU-96          [-1, 256, 25, 25]               0
#            Conv2d-97         [-1, 1024, 25, 25]         262,144
#       BatchNorm2d-98         [-1, 1024, 25, 25]           2,048
#              ReLU-99         [-1, 1024, 25, 25]               0
#       Bottleneck-100         [-1, 1024, 25, 25]               0
#           Conv2d-101          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-102          [-1, 256, 25, 25]             512
#             ReLU-103          [-1, 256, 25, 25]               0
#           Conv2d-104          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-105          [-1, 256, 25, 25]             512
#             ReLU-106          [-1, 256, 25, 25]               0
#           Conv2d-107         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-108         [-1, 1024, 25, 25]           2,048
#             ReLU-109         [-1, 1024, 25, 25]               0
#       Bottleneck-110         [-1, 1024, 25, 25]               0
#           Conv2d-111          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-112          [-1, 256, 25, 25]             512
#             ReLU-113          [-1, 256, 25, 25]               0
#           Conv2d-114          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-115          [-1, 256, 25, 25]             512
#             ReLU-116          [-1, 256, 25, 25]               0
#           Conv2d-117         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-118         [-1, 1024, 25, 25]           2,048
#             ReLU-119         [-1, 1024, 25, 25]               0
#       Bottleneck-120         [-1, 1024, 25, 25]               0
#           Conv2d-121          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-122          [-1, 256, 25, 25]             512
#             ReLU-123          [-1, 256, 25, 25]               0
#           Conv2d-124          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-125          [-1, 256, 25, 25]             512
#             ReLU-126          [-1, 256, 25, 25]               0
#           Conv2d-127         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-128         [-1, 1024, 25, 25]           2,048
#             ReLU-129         [-1, 1024, 25, 25]               0
#       Bottleneck-130         [-1, 1024, 25, 25]               0
#           Conv2d-131          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-132          [-1, 256, 25, 25]             512
#             ReLU-133          [-1, 256, 25, 25]               0
#           Conv2d-134          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-135          [-1, 256, 25, 25]             512
#             ReLU-136          [-1, 256, 25, 25]               0
#           Conv2d-137         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-138         [-1, 1024, 25, 25]           2,048
#             ReLU-139         [-1, 1024, 25, 25]               0
#       Bottleneck-140         [-1, 1024, 25, 25]               0
#           Conv2d-141          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-142          [-1, 256, 25, 25]             512
#             ReLU-143          [-1, 256, 25, 25]               0
#           Conv2d-144          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-145          [-1, 256, 25, 25]             512
#             ReLU-146          [-1, 256, 25, 25]               0
#           Conv2d-147         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-148         [-1, 1024, 25, 25]           2,048
#             ReLU-149         [-1, 1024, 25, 25]               0
#       Bottleneck-150         [-1, 1024, 25, 25]               0
#           Conv2d-151          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-152          [-1, 256, 25, 25]             512
#             ReLU-153          [-1, 256, 25, 25]               0
#           Conv2d-154          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-155          [-1, 256, 25, 25]             512
#             ReLU-156          [-1, 256, 25, 25]               0
#           Conv2d-157         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-158         [-1, 1024, 25, 25]           2,048
#             ReLU-159         [-1, 1024, 25, 25]               0
#       Bottleneck-160         [-1, 1024, 25, 25]               0
#           Conv2d-161          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-162          [-1, 256, 25, 25]             512
#             ReLU-163          [-1, 256, 25, 25]               0
#           Conv2d-164          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-165          [-1, 256, 25, 25]             512
#             ReLU-166          [-1, 256, 25, 25]               0
#           Conv2d-167         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-168         [-1, 1024, 25, 25]           2,048
#             ReLU-169         [-1, 1024, 25, 25]               0
#       Bottleneck-170         [-1, 1024, 25, 25]               0
#           Conv2d-171          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-172          [-1, 256, 25, 25]             512
#             ReLU-173          [-1, 256, 25, 25]               0
#           Conv2d-174          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-175          [-1, 256, 25, 25]             512
#             ReLU-176          [-1, 256, 25, 25]               0
#           Conv2d-177         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-178         [-1, 1024, 25, 25]           2,048
#             ReLU-179         [-1, 1024, 25, 25]               0
#       Bottleneck-180         [-1, 1024, 25, 25]               0
#           Conv2d-181          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-182          [-1, 256, 25, 25]             512
#             ReLU-183          [-1, 256, 25, 25]               0
#           Conv2d-184          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-185          [-1, 256, 25, 25]             512
#             ReLU-186          [-1, 256, 25, 25]               0
#           Conv2d-187         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-188         [-1, 1024, 25, 25]           2,048
#             ReLU-189         [-1, 1024, 25, 25]               0
#       Bottleneck-190         [-1, 1024, 25, 25]               0
#           Conv2d-191          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-192          [-1, 256, 25, 25]             512
#             ReLU-193          [-1, 256, 25, 25]               0
#           Conv2d-194          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-195          [-1, 256, 25, 25]             512
#             ReLU-196          [-1, 256, 25, 25]               0
#           Conv2d-197         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-198         [-1, 1024, 25, 25]           2,048
#             ReLU-199         [-1, 1024, 25, 25]               0
#       Bottleneck-200         [-1, 1024, 25, 25]               0
#           Conv2d-201          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-202          [-1, 256, 25, 25]             512
#             ReLU-203          [-1, 256, 25, 25]               0
#           Conv2d-204          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-205          [-1, 256, 25, 25]             512
#             ReLU-206          [-1, 256, 25, 25]               0
#           Conv2d-207         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-208         [-1, 1024, 25, 25]           2,048
#             ReLU-209         [-1, 1024, 25, 25]               0
#       Bottleneck-210         [-1, 1024, 25, 25]               0
#           Conv2d-211          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-212          [-1, 256, 25, 25]             512
#             ReLU-213          [-1, 256, 25, 25]               0
#           Conv2d-214          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-215          [-1, 256, 25, 25]             512
#             ReLU-216          [-1, 256, 25, 25]               0
#           Conv2d-217         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-218         [-1, 1024, 25, 25]           2,048
#             ReLU-219         [-1, 1024, 25, 25]               0
#       Bottleneck-220         [-1, 1024, 25, 25]               0
#           Conv2d-221          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-222          [-1, 256, 25, 25]             512
#             ReLU-223          [-1, 256, 25, 25]               0
#           Conv2d-224          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-225          [-1, 256, 25, 25]             512
#             ReLU-226          [-1, 256, 25, 25]               0
#           Conv2d-227         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-228         [-1, 1024, 25, 25]           2,048
#             ReLU-229         [-1, 1024, 25, 25]               0
#       Bottleneck-230         [-1, 1024, 25, 25]               0
#           Conv2d-231          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-232          [-1, 256, 25, 25]             512
#             ReLU-233          [-1, 256, 25, 25]               0
#           Conv2d-234          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-235          [-1, 256, 25, 25]             512
#             ReLU-236          [-1, 256, 25, 25]               0
#           Conv2d-237         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-238         [-1, 1024, 25, 25]           2,048
#             ReLU-239         [-1, 1024, 25, 25]               0
#       Bottleneck-240         [-1, 1024, 25, 25]               0
#           Conv2d-241          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-242          [-1, 256, 25, 25]             512
#             ReLU-243          [-1, 256, 25, 25]               0
#           Conv2d-244          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-245          [-1, 256, 25, 25]             512
#             ReLU-246          [-1, 256, 25, 25]               0
#           Conv2d-247         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-248         [-1, 1024, 25, 25]           2,048
#             ReLU-249         [-1, 1024, 25, 25]               0
#       Bottleneck-250         [-1, 1024, 25, 25]               0
#           Conv2d-251          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-252          [-1, 256, 25, 25]             512
#             ReLU-253          [-1, 256, 25, 25]               0
#           Conv2d-254          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-255          [-1, 256, 25, 25]             512
#             ReLU-256          [-1, 256, 25, 25]               0
#           Conv2d-257         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-258         [-1, 1024, 25, 25]           2,048
#             ReLU-259         [-1, 1024, 25, 25]               0
#       Bottleneck-260         [-1, 1024, 25, 25]               0
#           Conv2d-261          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-262          [-1, 256, 25, 25]             512
#             ReLU-263          [-1, 256, 25, 25]               0
#           Conv2d-264          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-265          [-1, 256, 25, 25]             512
#             ReLU-266          [-1, 256, 25, 25]               0
#           Conv2d-267         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-268         [-1, 1024, 25, 25]           2,048
#             ReLU-269         [-1, 1024, 25, 25]               0
#       Bottleneck-270         [-1, 1024, 25, 25]               0
#           Conv2d-271          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-272          [-1, 256, 25, 25]             512
#             ReLU-273          [-1, 256, 25, 25]               0
#           Conv2d-274          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-275          [-1, 256, 25, 25]             512
#             ReLU-276          [-1, 256, 25, 25]               0
#           Conv2d-277         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-278         [-1, 1024, 25, 25]           2,048
#             ReLU-279         [-1, 1024, 25, 25]               0
#       Bottleneck-280         [-1, 1024, 25, 25]               0
#           Conv2d-281          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-282          [-1, 256, 25, 25]             512
#             ReLU-283          [-1, 256, 25, 25]               0
#           Conv2d-284          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-285          [-1, 256, 25, 25]             512
#             ReLU-286          [-1, 256, 25, 25]               0
#           Conv2d-287         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-288         [-1, 1024, 25, 25]           2,048
#             ReLU-289         [-1, 1024, 25, 25]               0
#       Bottleneck-290         [-1, 1024, 25, 25]               0
#           Conv2d-291          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-292          [-1, 256, 25, 25]             512
#             ReLU-293          [-1, 256, 25, 25]               0
#           Conv2d-294          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-295          [-1, 256, 25, 25]             512
#             ReLU-296          [-1, 256, 25, 25]               0
#           Conv2d-297         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-298         [-1, 1024, 25, 25]           2,048
#             ReLU-299         [-1, 1024, 25, 25]               0
#       Bottleneck-300         [-1, 1024, 25, 25]               0
#           Conv2d-301          [-1, 256, 25, 25]         262,144
#      BatchNorm2d-302          [-1, 256, 25, 25]             512
#             ReLU-303          [-1, 256, 25, 25]               0
#           Conv2d-304          [-1, 256, 25, 25]         589,824
#      BatchNorm2d-305          [-1, 256, 25, 25]             512
#             ReLU-306          [-1, 256, 25, 25]               0
#           Conv2d-307         [-1, 1024, 25, 25]         262,144
#      BatchNorm2d-308         [-1, 1024, 25, 25]           2,048
#             ReLU-309         [-1, 1024, 25, 25]               0
#       Bottleneck-310         [-1, 1024, 25, 25]               0
#           Conv2d-311          [-1, 512, 25, 25]         524,288
#      BatchNorm2d-312          [-1, 512, 25, 25]           1,024
#             ReLU-313          [-1, 512, 25, 25]               0
#           Conv2d-314          [-1, 512, 13, 13]       2,359,296
#      BatchNorm2d-315          [-1, 512, 13, 13]           1,024
#             ReLU-316          [-1, 512, 13, 13]               0
#           Conv2d-317         [-1, 2048, 13, 13]       1,048,576
#      BatchNorm2d-318         [-1, 2048, 13, 13]           4,096
#           Conv2d-319         [-1, 2048, 13, 13]       2,097,152
#      BatchNorm2d-320         [-1, 2048, 13, 13]           4,096
#             ReLU-321         [-1, 2048, 13, 13]               0
#       Bottleneck-322         [-1, 2048, 13, 13]               0
#           Conv2d-323          [-1, 512, 13, 13]       1,048,576
#      BatchNorm2d-324          [-1, 512, 13, 13]           1,024
#             ReLU-325          [-1, 512, 13, 13]               0
#           Conv2d-326          [-1, 512, 13, 13]       2,359,296
#      BatchNorm2d-327          [-1, 512, 13, 13]           1,024
#             ReLU-328          [-1, 512, 13, 13]               0
#           Conv2d-329         [-1, 2048, 13, 13]       1,048,576
#      BatchNorm2d-330         [-1, 2048, 13, 13]           4,096
#             ReLU-331         [-1, 2048, 13, 13]               0
#       Bottleneck-332         [-1, 2048, 13, 13]               0
#           Conv2d-333          [-1, 512, 13, 13]       1,048,576
#      BatchNorm2d-334          [-1, 512, 13, 13]           1,024
#             ReLU-335          [-1, 512, 13, 13]               0
#           Conv2d-336          [-1, 512, 13, 13]       2,359,296
#      BatchNorm2d-337          [-1, 512, 13, 13]           1,024
#             ReLU-338          [-1, 512, 13, 13]               0
#           Conv2d-339         [-1, 2048, 13, 13]       1,048,576
#      BatchNorm2d-340         [-1, 2048, 13, 13]           4,096
#             ReLU-341         [-1, 2048, 13, 13]               0
#       Bottleneck-342         [-1, 2048, 13, 13]               0
# AdaptiveAvgPool2d-343           [-1, 2048, 1, 1]               0
#           Linear-344                    [-1, 3]           6,147
# ================================================================
# Total params: 42,506,307
# Trainable params: 18,717,699
# Non-trainable params: 23,788,608
# ----------------------------------------------------------------
# Input size (MB): 1.83
# Forward/backward pass size (MB): 1373.79
# Params size (MB): 162.15
# Estimated Total Size (MB): 1537.77
# ----------------------------------------------------------------

# %%
# prepare training data
from training_data import Normalizer

# decide how to transform data
img_normalizer = lambda x: (x / 255).transpose((0, 3, 1, 2)).astype(np.float32)
pos_normalizer = Normalizer(range=[[-100, 0, 0], [100, 500, 500]])
def make_image_tensor(data):
    """Convert ubyte image data to a 0.0-1.0 float32 torch tensor on the GPU."""
    return torch.tensor(img_normalizer(data)).to(device)
def make_position_tensor(data):
    """Convert position data to a normalized (-0.5 to 0.5) float32 torch tensor on the GPU."""
    return torch.tensor(pos_normalizer.normalize(data).astype(np.float32)).to(device)

batch_size = 96
data_generator = training_data.generator(batch_size)
# data_generator yields batches of (image, position) data
#  - images are 3D numpy arrays of shape (batch_size, height, width), with values in [0, 255]
#  - positions are 2D numpy arrays of shape (batch_size, (z, y, x)), with z values in microns and x, y in pixels 

# prepare validation data
n_validation_batches = 4
validation_data = [next(data_generator) for i in range(n_validation_batches)]
validation_images = make_image_tensor(np.concatenate([x[0] for x in validation_data]))
validation_positions = make_position_tensor(np.concatenate([x[1] for x in validation_data]))

# %%
# initialize the model
model = PipetteDetector()
model.to(device)

# Define a loss function and optimizer
criterion = nn.MSELoss()  # for regression
optimizer = optim.Adam(model.parameters(), lr=0.001)
# scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.99)

# %%
class TrainingHistory:
    def __init__(self):
        self.history = {'i': [], 'loss': []}

    def append(self, i, prediction, target, loss):
        self.history['i'].append(i)
        self.history['loss'].append(loss)
        result = TrainingHistory.analyze_prediction(prediction, target)
        for k,v in result.items():
            if k not in self.history:
                self.history[k] = []
            self.history[k].append(v)

    def __getitem__(self, key):
        return np.array(self.history[key])
    
    def plot(self, loss_ax, accuracy_ax, label=None):
        loss_ax.plot(self.history['i'], self.history['rmse_xy'], label=label+' xy RMSE')
        loss_ax.plot(self.history['i'], self.history['rmse_z'], label=label+' z RMSE')
        loss_ax.set_yscale('log')
        loss_ax.legend()
        accuracy_ax.plot(self.history['i'], self.history['accuracy_xy'], label=label+' xy accuracy')
        accuracy_ax.plot(self.history['i'], self.history['accuracy_z'], label=label+' z accuracy')
        accuracy_ax.set_ylim(0, 1)
        accuracy_ax.legend()

    @staticmethod
    def analyze_prediction(predicted_pos, target_pos, radius=0.02):
        predicted_pos = predicted_pos.cpu().detach().clone().numpy()
        target_pos = target_pos.cpu().detach().clone().numpy()
        predicted_z_sign = np.sign(predicted_pos[:, 0])
        target_z_sign = np.sign(target_pos[:, 0])
        result = {
            'rmse_xy': ((predicted_pos - target_pos)[:, 1:3]**2).mean()**0.5,
            'rmse_z': ((predicted_pos - target_pos)[:, 0]**2).mean()**0.5,
            'n_correct_xy': (((predicted_pos - target_pos)[:, 1:3]**2).sum(axis=1)**0.5 < radius).sum(),
            'n_correct_z': (predicted_z_sign == target_z_sign).sum(),
            'batch_size': predicted_pos.shape[0],
        }
        result['accuracy_xy'] = result['n_correct_xy'] / result['batch_size']
        result['accuracy_z'] = result['n_correct_z'] / result['batch_size']
        return result

# %%
# Train the model

training_history = TrainingHistory()
validation_history = TrainingHistory()
try:
    for i, data in enumerate(data_generator):
        # inputs is a 4D numpy array of shape (batch_size, height, width, channels), normalized to [0, 1]
        # labels is a 2D numpy array of shape (batch_size, 3), normalized using training_data.output_norm
        inputs, labels = data
        image_tensor = make_image_tensor(inputs)
        position_tensor = make_position_tensor(labels)

        # zero the parameter gradients (otherwise they accumulate)
        optimizer.zero_grad()

        # run model, calculate loss, and backpropagate
        output = model(image_tensor)
        loss = criterion(output, position_tensor)
        loss.backward()
        optimizer.step()
        # scheduler.step()

        # track performance over time
        training_history.append(i, output, position_tensor, loss.item())
        del image_tensor, position_tensor, output, loss
        torch.cuda.empty_cache()

        if i % 10 == 9:
            with torch.no_grad():
                val_output = model(validation_images)
                val_loss = criterion(val_output, validation_positions)
                validation_history.append(i, val_output, validation_positions, val_loss.item())

            recent_size = 10
            training_loss = training_history['loss'][-recent_size:]
            training_accuracy = training_history['accuracy_xy'][-recent_size:].mean()
            val_loss = validation_history['loss'][-1]
            validation_accuracy = validation_history['accuracy_xy'][-1]
            validation_z_accuracy = validation_history['accuracy_z'][-1]
            print(
                f'[step {i:06d}] avg sqrt loss: {(training_loss**0.5).mean():0.6f}\n'
                f'              final sqrt loss: {training_loss[-1]**0.5:0.6f}\n'
                f'              val sqrt loss: {val_loss**0.5:0.6f}\n'
                f'              val xy rmse: {validation_history["rmse_xy"][-1]:0.6f}\n'
                f'              val z rmse: {validation_history["rmse_z"][-1]:0.6f}\n'
                f'              training xy accuracy: {100 * training_accuracy:0.2f}%\n'
                f'              validation xy accuracy: {100 * validation_accuracy:0.2f}%\n'
                f'              validation z accuracy: {100 * validation_z_accuracy:0.2f}%\n'
            )
            del val_output, val_loss
            torch.cuda.empty_cache()
            
        if i % 100 == 99:
            print("Saving model..")
            torch.save(model.state_dict(), save_path)

except KeyboardInterrupt:
    print('Interrupted, saving..')
    torch.save(model.state_dict(), save_path)

print('Finished Training')

fig, ax = plt.subplots(2, 1, sharex=True, figsize=(10, 6))
training_history.plot(ax[0], ax[1], label='training')
validation_history.plot(ax[0], ax[1], label='validation')
# Out:
# [step 000009] avg sqrt loss: 0.302092
#               final sqrt loss: 0.209533
#               val sqrt loss: 0.218234
#               val xy rmse: 0.261543
#               val z rmse: 0.077899
#               training xy accuracy: 0.10%
#               validation xy accuracy: 0.00%
#               validation z accuracy: 63.28%
#
# [step 000019] avg sqrt loss: 0.181011
#               final sqrt loss: 0.175638
#               val sqrt loss: 0.176712
#               val xy rmse: 0.209678
#               val z rmse: 0.075840
#               training xy accuracy: 1.67%
#               validation xy accuracy: 2.34%
#               validation z accuracy: 63.54%
#
# [step 000029] avg sqrt loss: 0.146718
#               final sqrt loss: 0.106391
#               val sqrt loss: 0.153076
#               val xy rmse: 0.179038
#               val z rmse: 0.078665
#               training xy accuracy: 1.56%
#               validation xy accuracy: 1.82%
#               validation z accuracy: 61.72%
#
# [step 000039] avg sqrt loss: 0.139507
#               final sqrt loss: 0.126610
#               val sqrt loss: 0.153637
#               val xy rmse: 0.182486
#               val z rmse: 0.064891
#               training xy accuracy: 1.56%
#               validation xy accuracy: 2.60%
#               validation z accuracy: 65.89%
#
# [step 000049] avg sqrt loss: 0.129645
#               final sqrt loss: 0.137758
#               val sqrt loss: 0.155936
#               val xy rmse: 0.185966
#               val z rmse: 0.061497
#               training xy accuracy: 4.06%
#               validation xy accuracy: 7.03%
#               validation z accuracy: 65.89%
#
# [step 000059] avg sqrt loss: 0.125805
#               final sqrt loss: 0.121306
#               val sqrt loss: 0.153816
#               val xy rmse: 0.183565
#               val z rmse: 0.059880
#               training xy accuracy: 3.65%
#               validation xy accuracy: 2.08%
#               validation z accuracy: 66.41%
#
# [step 000069] avg sqrt loss: 0.133403
#               final sqrt loss: 0.122294
#               val sqrt loss: 0.143607
#               val xy rmse: 0.171075
#               val z rmse: 0.057752
#               training xy accuracy: 3.75%
#               validation xy accuracy: 3.39%
#               validation z accuracy: 67.19%
#
# [step 000079] avg sqrt loss: 0.116972
#               final sqrt loss: 0.091530
#               val sqrt loss: 0.130708
#               val xy rmse: 0.154001
#               val z rmse: 0.061817
#               training xy accuracy: 3.96%
#               validation xy accuracy: 3.91%
#               validation z accuracy: 68.23%
#
# [step 000089] avg sqrt loss: 0.120199
#               final sqrt loss: 0.096304
#               val sqrt loss: 0.141918
#               val xy rmse: 0.167669
#               val z rmse: 0.064774
#               training xy accuracy: 2.40%
#               validation xy accuracy: 4.17%
#               validation z accuracy: 66.41%
#
# [step 000099] avg sqrt loss: 0.113344
#               final sqrt loss: 0.149895
#               val sqrt loss: 0.134032
#               val xy rmse: 0.157944
#               val z rmse: 0.063257
#               training xy accuracy: 2.81%
#               validation xy accuracy: 5.21%
#               validation z accuracy: 67.19%
#
# Saving model..
# [step 000109] avg sqrt loss: 0.114279
#               final sqrt loss: 0.152662
#               val sqrt loss: 0.136400
#               val xy rmse: 0.159346
#               val z rmse: 0.070941
#               training xy accuracy: 5.73%
#               validation xy accuracy: 6.25%
#               validation z accuracy: 64.06%
#
# [step 000119] avg sqrt loss: 0.113171
#               final sqrt loss: 0.108986
#               val sqrt loss: 0.134581
#               val xy rmse: 0.157187
#               val z rmse: 0.070149
#               training xy accuracy: 8.44%
#               validation xy accuracy: 3.12%
#               validation z accuracy: 64.06%
#
# [step 000129] avg sqrt loss: 0.110223
#               final sqrt loss: 0.089592
#               val sqrt loss: 0.135476
#               val xy rmse: 0.160709
#               val z rmse: 0.058365
#               training xy accuracy: 7.81%
#               validation xy accuracy: 5.73%
#               validation z accuracy: 66.41%
#
# [step 000139] avg sqrt loss: 0.103025
#               final sqrt loss: 0.124022
#               val sqrt loss: 0.128428
#               val xy rmse: 0.152070
#               val z rmse: 0.056836
#               training xy accuracy: 4.48%
#               validation xy accuracy: 4.95%
#               validation z accuracy: 66.93%
#
# [step 000149] avg sqrt loss: 0.101042
#               final sqrt loss: 0.093748
#               val sqrt loss: 0.121862
#               val xy rmse: 0.144441
#               val z rmse: 0.053144
#               training xy accuracy: 5.62%
#               validation xy accuracy: 12.50%
#               validation z accuracy: 69.01%
#
# [step 000159] avg sqrt loss: 0.107780
#               final sqrt loss: 0.110811
#               val sqrt loss: 0.125779
#               val xy rmse: 0.149572
#               val z rmse: 0.052134
#               training xy accuracy: 6.67%
#               validation xy accuracy: 10.16%
#               validation z accuracy: 70.31%
#
# [step 000169] avg sqrt loss: 0.110138
#               final sqrt loss: 0.162295
#               val sqrt loss: 0.130401
#               val xy rmse: 0.154638
#               val z rmse: 0.056455
#               training xy accuracy: 7.08%
#               validation xy accuracy: 7.03%
#               validation z accuracy: 70.83%
#
# [step 000179] avg sqrt loss: 0.100174
#               final sqrt loss: 0.118458
#               val sqrt loss: 0.128898
#               val xy rmse: 0.153510
#               val z rmse: 0.052094
#               training xy accuracy: 5.73%
#               validation xy accuracy: 8.85%
#               validation z accuracy: 65.36%
#
# [step 000189] avg sqrt loss: 0.093852
#               final sqrt loss: 0.117980
#               val sqrt loss: 0.119247
#               val xy rmse: 0.141526
#               val z rmse: 0.050997
#               training xy accuracy: 6.88%
#               validation xy accuracy: 12.76%
#               validation z accuracy: 68.75%
#
# [step 000199] avg sqrt loss: 0.096027
#               final sqrt loss: 0.099773
#               val sqrt loss: 0.123212
#               val xy rmse: 0.145544
#               val z rmse: 0.056364
#               training xy accuracy: 6.25%
#               validation xy accuracy: 12.24%
#               validation z accuracy: 67.45%
#
# Saving model..
# [step 000209] avg sqrt loss: 0.121495
#               final sqrt loss: 0.130893
#               val sqrt loss: 0.130897
#               val xy rmse: 0.154563
#               val z rmse: 0.060187
#               training xy accuracy: 7.29%
#               validation xy accuracy: 8.33%
#               validation z accuracy: 66.67%
#
# [step 000219] avg sqrt loss: 0.092777
#               final sqrt loss: 0.126530
#               val sqrt loss: 0.128234
#               val xy rmse: 0.151822
#               val z rmse: 0.056852
#               training xy accuracy: 7.40%
#               validation xy accuracy: 3.39%
#               validation z accuracy: 68.23%
#
# [step 000229] avg sqrt loss: 0.094471
#               final sqrt loss: 0.077770
#               val sqrt loss: 0.117457
#               val xy rmse: 0.138495
#               val z rmse: 0.055019
#               training xy accuracy: 8.12%
#               validation xy accuracy: 8.07%
#               validation z accuracy: 67.45%
#
# [step 000239] avg sqrt loss: 0.109673
#               final sqrt loss: 0.137859
#               val sqrt loss: 0.122278
#               val xy rmse: 0.144597
#               val z rmse: 0.055128
#               training xy accuracy: 7.40%
#               validation xy accuracy: 11.46%
#               validation z accuracy: 67.71%
#
# [step 000249] avg sqrt loss: 0.104629
#               final sqrt loss: 0.074442
#               val sqrt loss: 0.132730
#               val xy rmse: 0.157754
#               val z rmse: 0.055492
#               training xy accuracy: 5.83%
#               validation xy accuracy: 3.12%
#               validation z accuracy: 68.49%
#
# [step 000259] avg sqrt loss: 0.110506
#               final sqrt loss: 0.096362
#               val sqrt loss: 0.138058
#               val xy rmse: 0.165408
#               val z rmse: 0.049596
#               training xy accuracy: 6.56%
#               validation xy accuracy: 11.20%
#               validation z accuracy: 69.01%
#
# [step 000269] avg sqrt loss: 0.085985
#               final sqrt loss: 0.086820
#               val sqrt loss: 0.126737
#               val xy rmse: 0.150981
#               val z rmse: 0.050950
#               training xy accuracy: 6.98%
#               validation xy accuracy: 3.39%
#               validation z accuracy: 69.27%
#
# [step 000279] avg sqrt loss: 0.089249
#               final sqrt loss: 0.067559
#               val sqrt loss: 0.133619
#               val xy rmse: 0.159492
#               val z rmse: 0.051836
#               training xy accuracy: 6.56%
#               validation xy accuracy: 7.29%
#               validation z accuracy: 69.01%
#
# [step 000289] avg sqrt loss: 0.098402
#               final sqrt loss: 0.083060
#               val sqrt loss: 0.125948
#               val xy rmse: 0.149102
#               val z rmse: 0.055911
#               training xy accuracy: 6.67%
#               validation xy accuracy: 15.62%
#               validation z accuracy: 68.75%
#
# [step 000299] avg sqrt loss: 0.090594
#               final sqrt loss: 0.048966
#               val sqrt loss: 0.122162
#               val xy rmse: 0.145249
#               val z rmse: 0.050760
#               training xy accuracy: 10.00%
#               validation xy accuracy: 10.16%
#               validation z accuracy: 69.79%
#
# Saving model..
# [step 000309] avg sqrt loss: 0.092056
#               final sqrt loss: 0.105508
#               val sqrt loss: 0.118301
#               val xy rmse: 0.139318
#               val z rmse: 0.056268
#               training xy accuracy: 6.67%
#               validation xy accuracy: 8.85%
#               validation z accuracy: 69.53%
#
# [step 000319] avg sqrt loss: 0.077230
#               final sqrt loss: 0.056406
#               val sqrt loss: 0.114872
#               val xy rmse: 0.135292
#               val z rmse: 0.054579
#               training xy accuracy: 9.27%
#               validation xy accuracy: 15.36%
#               validation z accuracy: 68.49%
#
# [step 000329] avg sqrt loss: 0.076847
#               final sqrt loss: 0.075762
#               val sqrt loss: 0.113392
#               val xy rmse: 0.132305
#               val z rmse: 0.059698
#               training xy accuracy: 8.12%
#               validation xy accuracy: 14.58%
#               validation z accuracy: 66.67%
#
# [step 000339] avg sqrt loss: 0.093803
#               final sqrt loss: 0.043538
#               val sqrt loss: 0.113243
#               val xy rmse: 0.133299
#               val z rmse: 0.054175
#               training xy accuracy: 8.12%
#               validation xy accuracy: 13.28%
#               validation z accuracy: 67.71%
#
# [step 000349] avg sqrt loss: 0.073944
#               final sqrt loss: 0.079293
#               val sqrt loss: 0.120252
#               val xy rmse: 0.143263
#               val z rmse: 0.048298
#               training xy accuracy: 10.31%
#               validation xy accuracy: 14.06%
#               validation z accuracy: 70.05%
#
# [step 000359] avg sqrt loss: 0.094382
#               final sqrt loss: 0.127267
#               val sqrt loss: 0.110027
#               val xy rmse: 0.130069
#               val z rmse: 0.049819
#               training xy accuracy: 10.62%
#               validation xy accuracy: 20.05%
#               validation z accuracy: 69.79%
#
# [step 000369] avg sqrt loss: 0.073192
#               final sqrt loss: 0.036595
#               val sqrt loss: 0.108386
#               val xy rmse: 0.128011
#               val z rmse: 0.049686
#               training xy accuracy: 10.52%
#               validation xy accuracy: 11.98%
#               validation z accuracy: 69.27%
#
# [step 000379] avg sqrt loss: 0.085649
#               final sqrt loss: 0.084067
#               val sqrt loss: 0.108825
#               val xy rmse: 0.128126
#               val z rmse: 0.051924
#               training xy accuracy: 10.21%
#               validation xy accuracy: 18.23%
#               validation z accuracy: 67.45%
#
# [step 000389] avg sqrt loss: 0.087911
#               final sqrt loss: 0.090785
#               val sqrt loss: 0.117143
#               val xy rmse: 0.137869
#               val z rmse: 0.056139
#               training xy accuracy: 10.83%
#               validation xy accuracy: 0.52%
#               validation z accuracy: 67.45%
#
# [step 000399] avg sqrt loss: 0.099361
#               final sqrt loss: 0.121935
#               val sqrt loss: 0.111799
#               val xy rmse: 0.132651
#               val z rmse: 0.048009
#               training xy accuracy: 9.48%
#               validation xy accuracy: 9.64%
#               validation z accuracy: 69.53%
#
# Saving model..
# [step 000409] avg sqrt loss: 0.090217
#               final sqrt loss: 0.103126
#               val sqrt loss: 0.112232
#               val xy rmse: 0.133185
#               val z rmse: 0.048081
#               training xy accuracy: 11.77%
#               validation xy accuracy: 16.67%
#               validation z accuracy: 69.53%
#
# [step 000419] avg sqrt loss: 0.083335
#               final sqrt loss: 0.053461
#               val sqrt loss: 0.107990
#               val xy rmse: 0.127875
#               val z rmse: 0.047765
#               training xy accuracy: 14.06%
#               validation xy accuracy: 13.02%
#               validation z accuracy: 70.05%
#
# [step 000429] avg sqrt loss: 0.082332
#               final sqrt loss: 0.100441
#               val sqrt loss: 0.105200
#               val xy rmse: 0.124591
#               val z rmse: 0.046427
#               training xy accuracy: 10.00%
#               validation xy accuracy: 7.55%
#               validation z accuracy: 70.05%
#
# [step 000439] avg sqrt loss: 0.075136
#               final sqrt loss: 0.071090
#               val sqrt loss: 0.117956
#               val xy rmse: 0.140682
#               val z rmse: 0.046455
#               training xy accuracy: 11.67%
#               validation xy accuracy: 5.21%
#               validation z accuracy: 69.27%
#
# [step 000449] avg sqrt loss: 0.094706
#               final sqrt loss: 0.065423
#               val sqrt loss: 0.110766
#               val xy rmse: 0.130781
#               val z rmse: 0.050991
#               training xy accuracy: 5.94%
#               validation xy accuracy: 19.27%
#               validation z accuracy: 67.71%
#
# [step 000459] avg sqrt loss: 0.083696
#               final sqrt loss: 0.159956
#               val sqrt loss: 0.112321
#               val xy rmse: 0.133218
#               val z rmse: 0.048521
#               training xy accuracy: 12.29%
#               validation xy accuracy: 23.18%
#               validation z accuracy: 70.05%
#
# [step 000469] avg sqrt loss: 0.098701
#               final sqrt loss: 0.099521
#               val sqrt loss: 0.112366
#               val xy rmse: 0.132144
#               val z rmse: 0.054354
#               training xy accuracy: 15.73%
#               validation xy accuracy: 25.00%
#               validation z accuracy: 70.05%
#
# [step 000479] avg sqrt loss: 0.091297
#               final sqrt loss: 0.051416
#               val sqrt loss: 0.108904
#               val xy rmse: 0.129190
#               val z rmse: 0.046908
#               training xy accuracy: 11.98%
#               validation xy accuracy: 17.45%
#               validation z accuracy: 70.31%
#
# [step 000489] avg sqrt loss: 0.073499
#               final sqrt loss: 0.100863
#               val sqrt loss: 0.117864
#               val xy rmse: 0.140467
#               val z rmse: 0.047050
#               training xy accuracy: 12.92%
#               validation xy accuracy: 13.80%
#               validation z accuracy: 68.23%
#
# [step 000499] avg sqrt loss: 0.076489
#               final sqrt loss: 0.096777
#               val sqrt loss: 0.114938
#               val xy rmse: 0.136054
#               val z rmse: 0.051098
#               training xy accuracy: 15.10%
#               validation xy accuracy: 12.50%
#               validation z accuracy: 67.71%
#
# Saving model..
# [step 000509] avg sqrt loss: 0.080589
#               final sqrt loss: 0.113638
#               val sqrt loss: 0.109914
#               val xy rmse: 0.129854
#               val z rmse: 0.050190
#               training xy accuracy: 13.85%
#               validation xy accuracy: 9.11%
#               validation z accuracy: 67.97%
#
# [step 000519] avg sqrt loss: 0.102316
#               final sqrt loss: 0.112034
#               val sqrt loss: 0.112972
#               val xy rmse: 0.133740
#               val z rmse: 0.050155
#               training xy accuracy: 14.37%
#               validation xy accuracy: 5.47%
#               validation z accuracy: 68.75%
#
# [step 000529] avg sqrt loss: 0.081703
#               final sqrt loss: 0.077079
#               val sqrt loss: 0.110152
#               val xy rmse: 0.130646
#               val z rmse: 0.047581
#               training xy accuracy: 11.15%
#               validation xy accuracy: 15.89%
#               validation z accuracy: 67.45%
#
# [step 000539] avg sqrt loss: 0.085636
#               final sqrt loss: 0.049677
#               val sqrt loss: 0.111469
#               val xy rmse: 0.132152
#               val z rmse: 0.048450
#               training xy accuracy: 9.79%
#               validation xy accuracy: 3.12%
#               validation z accuracy: 69.53%
#
# [step 000549] avg sqrt loss: 0.073646
#               final sqrt loss: 0.092253
#               val sqrt loss: 0.110653
#               val xy rmse: 0.131268
#               val z rmse: 0.047636
#               training xy accuracy: 6.35%
#               validation xy accuracy: 7.55%
#               validation z accuracy: 69.53%
#
# [step 000559] avg sqrt loss: 0.073175
#               final sqrt loss: 0.076145
#               val sqrt loss: 0.111335
#               val xy rmse: 0.129950
#               val z rmse: 0.058417
#               training xy accuracy: 9.38%
#               validation xy accuracy: 18.49%
#               validation z accuracy: 66.67%
#
# [step 000569] avg sqrt loss: 0.078118
#               final sqrt loss: 0.124133
#               val sqrt loss: 0.119668
#               val xy rmse: 0.142573
#               val z rmse: 0.048032
#               training xy accuracy: 10.94%
#               validation xy accuracy: 15.10%
#               validation z accuracy: 69.53%
#
# [step 000579] avg sqrt loss: 0.060821
#               final sqrt loss: 0.052597
#               val sqrt loss: 0.130243
#               val xy rmse: 0.156362
#               val z rmse: 0.044627
#               training xy accuracy: 13.54%
#               validation xy accuracy: 17.97%
#               validation z accuracy: 70.57%
#
# [step 000589] avg sqrt loss: 0.074721
#               final sqrt loss: 0.112935
#               val sqrt loss: 0.110458
#               val xy rmse: 0.131108
#               val z rmse: 0.047158
#               training xy accuracy: 16.98%
#               validation xy accuracy: 21.61%
#               validation z accuracy: 70.05%
#
# [step 000599] avg sqrt loss: 0.089424
#               final sqrt loss: 0.140818
#               val sqrt loss: 0.108990
#               val xy rmse: 0.129171
#               val z rmse: 0.047607
#               training xy accuracy: 20.83%
#               validation xy accuracy: 14.84%
#               validation z accuracy: 69.79%
#
# Saving model..
# [step 000609] avg sqrt loss: 0.081745
#               final sqrt loss: 0.082840
#               val sqrt loss: 0.106983
#               val xy rmse: 0.126846
#               val z rmse: 0.046436
#               training xy accuracy: 10.52%
#               validation xy accuracy: 7.29%
#               validation z accuracy: 70.83%
#
# [step 000619] avg sqrt loss: 0.084299
#               final sqrt loss: 0.113131
#               val sqrt loss: 0.115312
#               val xy rmse: 0.137627
#               val z rmse: 0.044811
#               training xy accuracy: 12.08%
#               validation xy accuracy: 5.73%
#               validation z accuracy: 70.31%
#
# [step 000629] avg sqrt loss: 0.086689
#               final sqrt loss: 0.128086
#               val sqrt loss: 0.110375
#               val xy rmse: 0.131306
#               val z rmse: 0.045444
#               training xy accuracy: 10.31%
#               validation xy accuracy: 7.55%
#               validation z accuracy: 69.27%
#
# [step 000639] avg sqrt loss: 0.094696
#               final sqrt loss: 0.131589
#               val sqrt loss: 0.112323
#               val xy rmse: 0.134064
#               val z rmse: 0.043618
#               training xy accuracy: 8.23%
#               validation xy accuracy: 1.30%
#               validation z accuracy: 71.09%
#
# [step 000649] avg sqrt loss: 0.080872
#               final sqrt loss: 0.062883
#               val sqrt loss: 0.113552
#               val xy rmse: 0.135561
#               val z rmse: 0.043916
#               training xy accuracy: 6.88%
#               validation xy accuracy: 3.65%
#               validation z accuracy: 72.14%
#
# [step 000659] avg sqrt loss: 0.078755
#               final sqrt loss: 0.070841
#               val sqrt loss: 0.118553
#               val xy rmse: 0.140164
#               val z rmse: 0.053598
#               training xy accuracy: 10.10%
#               validation xy accuracy: 23.70%
#               validation z accuracy: 69.01%
#
# [step 000669] avg sqrt loss: 0.064983
#               final sqrt loss: 0.079639
#               val sqrt loss: 0.110478
#               val xy rmse: 0.131022
#               val z rmse: 0.047774
#               training xy accuracy: 16.67%
#               validation xy accuracy: 26.82%
#               validation z accuracy: 70.83%
#
# [step 000679] avg sqrt loss: 0.073834
#               final sqrt loss: 0.051907
#               val sqrt loss: 0.116586
#               val xy rmse: 0.138896
#               val z rmse: 0.046824
#               training xy accuracy: 15.10%
#               validation xy accuracy: 9.90%
#               validation z accuracy: 69.01%
#
# [step 000689] avg sqrt loss: 0.068102
#               final sqrt loss: 0.092597
#               val sqrt loss: 0.109602
#               val xy rmse: 0.130179
#               val z rmse: 0.046305
#               training xy accuracy: 16.98%
#               validation xy accuracy: 23.44%
#               validation z accuracy: 70.31%
#
# [step 000699] avg sqrt loss: 0.090634
#               final sqrt loss: 0.104861
#               val sqrt loss: 0.106741
#               val xy rmse: 0.126698
#               val z rmse: 0.045562
#               training xy accuracy: 16.15%
#               validation xy accuracy: 33.33%
#               validation z accuracy: 68.49%
#
# Saving model..
# [step 000709] avg sqrt loss: 0.071338
#               final sqrt loss: 0.072239
#               val sqrt loss: 0.112656
#               val xy rmse: 0.133572
#               val z rmse: 0.048899
#               training xy accuracy: 12.60%
#               validation xy accuracy: 22.66%
#               validation z accuracy: 67.71%
#
# [step 000719] avg sqrt loss: 0.082527
#               final sqrt loss: 0.066223
#               val sqrt loss: 0.123309
#               val xy rmse: 0.147139
#               val z rmse: 0.048120
#               training xy accuracy: 14.37%
#               validation xy accuracy: 9.38%
#               validation z accuracy: 70.31%
#
# [step 000729] avg sqrt loss: 0.070138
#               final sqrt loss: 0.044686
#               val sqrt loss: 0.109083
#               val xy rmse: 0.129552
#               val z rmse: 0.046148
#               training xy accuracy: 13.44%
#               validation xy accuracy: 14.84%
#               validation z accuracy: 69.27%
#
# [step 000739] avg sqrt loss: 0.082325
#               final sqrt loss: 0.144358
#               val sqrt loss: 0.113160
#               val xy rmse: 0.134851
#               val z rmse: 0.045236
#               training xy accuracy: 18.65%
#               validation xy accuracy: 14.84%
#               validation z accuracy: 69.79%
#
# [step 000749] avg sqrt loss: 0.068225
#               final sqrt loss: 0.053317
#               val sqrt loss: 0.122605
#               val xy rmse: 0.146775
#               val z rmse: 0.044828
#               training xy accuracy: 16.04%
#               validation xy accuracy: 13.80%
#               validation z accuracy: 69.53%
#
# [step 000759] avg sqrt loss: 0.079833
#               final sqrt loss: 0.107939
#               val sqrt loss: 0.120696
#               val xy rmse: 0.144009
#               val z rmse: 0.047176
#               training xy accuracy: 15.52%
#               validation xy accuracy: 13.28%
#               validation z accuracy: 70.83%
#
# [step 000769] avg sqrt loss: 0.081785
#               final sqrt loss: 0.141638
#               val sqrt loss: 0.108370
#               val xy rmse: 0.128901
#               val z rmse: 0.044732
#               training xy accuracy: 11.77%
#               validation xy accuracy: 22.14%
#               validation z accuracy: 69.79%
#
# [step 000779] avg sqrt loss: 0.082263
#               final sqrt loss: 0.103767
#               val sqrt loss: 0.122806
#               val xy rmse: 0.146749
#               val z rmse: 0.046621
#               training xy accuracy: 20.10%
#               validation xy accuracy: 23.44%
#               validation z accuracy: 70.31%
#
# [step 000789] avg sqrt loss: 0.088767
#               final sqrt loss: 0.050936
#               val sqrt loss: 0.118914
#               val xy rmse: 0.141776
#               val z rmse: 0.047120
#               training xy accuracy: 16.46%
#               validation xy accuracy: 14.32%
#               validation z accuracy: 70.31%
#
# [step 000799] avg sqrt loss: 0.075282
#               final sqrt loss: 0.092519
#               val sqrt loss: 0.122326
#               val xy rmse: 0.145836
#               val z rmse: 0.048526
#               training xy accuracy: 16.56%
#               validation xy accuracy: 3.39%
#               validation z accuracy: 71.09%
#
# Saving model..
# [step 000809] avg sqrt loss: 0.104698
#               final sqrt loss: 0.098055
#               val sqrt loss: 0.118384
#               val xy rmse: 0.141115
#               val z rmse: 0.047089
#               training xy accuracy: 13.33%
#               validation xy accuracy: 5.99%
#               validation z accuracy: 69.79%
#
# [step 000819] avg sqrt loss: 0.084402
#               final sqrt loss: 0.050032
#               val sqrt loss: 0.112817
#               val xy rmse: 0.134586
#               val z rmse: 0.044226
#               training xy accuracy: 11.88%
#               validation xy accuracy: 17.71%
#               validation z accuracy: 70.31%
#
# [step 000829] avg sqrt loss: 0.083257
#               final sqrt loss: 0.043025
#               val sqrt loss: 0.111149
#               val xy rmse: 0.132517
#               val z rmse: 0.044058
#               training xy accuracy: 17.19%
#               validation xy accuracy: 17.45%
#               validation z accuracy: 70.57%
#
# [step 000839] avg sqrt loss: 0.060783
#               final sqrt loss: 0.054298
#               val sqrt loss: 0.113754
#               val xy rmse: 0.136130
#               val z rmse: 0.041918
#               training xy accuracy: 13.23%
#               validation xy accuracy: 5.21%
#               validation z accuracy: 71.35%
#
# [step 000849] avg sqrt loss: 0.078812
#               final sqrt loss: 0.059194
#               val sqrt loss: 0.113057
#               val xy rmse: 0.135077
#               val z rmse: 0.043056
#               training xy accuracy: 12.60%
#               validation xy accuracy: 12.24%
#               validation z accuracy: 71.09%
#
# [step 000859] avg sqrt loss: 0.072987
#               final sqrt loss: 0.042294
#               val sqrt loss: 0.115717
#               val xy rmse: 0.137779
#               val z rmse: 0.046957
#               training xy accuracy: 15.21%
#               validation xy accuracy: 17.45%
#               validation z accuracy: 70.83%
#
# [step 000869] avg sqrt loss: 0.070721
#               final sqrt loss: 0.039850
#               val sqrt loss: 0.110346
#               val xy rmse: 0.130846
#               val z rmse: 0.047825
#               training xy accuracy: 20.10%
#               validation xy accuracy: 13.80%
#               validation z accuracy: 70.31%
#
# [step 000879] avg sqrt loss: 0.084167
#               final sqrt loss: 0.101207
#               val sqrt loss: 0.106247
#               val xy rmse: 0.125924
#               val z rmse: 0.046388
#               training xy accuracy: 11.98%
#               validation xy accuracy: 17.97%
#               validation z accuracy: 68.23%
#
# [step 000889] avg sqrt loss: 0.081531
#               final sqrt loss: 0.086692
#               val sqrt loss: 0.109821
#               val xy rmse: 0.129315
#               val z rmse: 0.052319
#               training xy accuracy: 17.71%
#               validation xy accuracy: 4.69%
#               validation z accuracy: 68.75%
#
# [step 000899] avg sqrt loss: 0.072322
#               final sqrt loss: 0.121215
#               val sqrt loss: 0.113774
#               val xy rmse: 0.134422
#               val z rmse: 0.051917
#               training xy accuracy: 10.21%
#               validation xy accuracy: 2.34%
#               validation z accuracy: 66.15%
#
# Saving model..
# [step 000909] avg sqrt loss: 0.093461
#               final sqrt loss: 0.105008
#               val sqrt loss: 0.113714
#               val xy rmse: 0.135015
#               val z rmse: 0.048313
#               training xy accuracy: 13.54%
#               validation xy accuracy: 9.38%
#               validation z accuracy: 70.57%
#
# [step 000919] avg sqrt loss: 0.081243
#               final sqrt loss: 0.131960
#               val sqrt loss: 0.115238
#               val xy rmse: 0.137203
#               val z rmse: 0.046799
#               training xy accuracy: 14.69%
#               validation xy accuracy: 24.48%
#               validation z accuracy: 68.49%
#
# [step 000929] avg sqrt loss: 0.081464
#               final sqrt loss: 0.056808
#               val sqrt loss: 0.106045
#               val xy rmse: 0.126321
#               val z rmse: 0.042696
#               training xy accuracy: 16.46%
#               validation xy accuracy: 27.86%
#               validation z accuracy: 71.09%
#
# [step 000939] avg sqrt loss: 0.092429
#               final sqrt loss: 0.093257
#               val sqrt loss: 0.103203
#               val xy rmse: 0.122577
#               val z rmse: 0.043615
#               training xy accuracy: 19.79%
#               validation xy accuracy: 36.46%
#               validation z accuracy: 70.31%
#
# [step 000949] avg sqrt loss: 0.061757
#               final sqrt loss: 0.037838
#               val sqrt loss: 0.107082
#               val xy rmse: 0.127476
#               val z rmse: 0.043581
#               training xy accuracy: 28.23%
#               validation xy accuracy: 20.05%
#               validation z accuracy: 70.31%
#
# [step 000959] avg sqrt loss: 0.076445
#               final sqrt loss: 0.083216
#               val sqrt loss: 0.108192
#               val xy rmse: 0.128739
#               val z rmse: 0.044374
#               training xy accuracy: 20.62%
#               validation xy accuracy: 11.20%
#               validation z accuracy: 70.05%
#
# [step 000969] avg sqrt loss: 0.064630
#               final sqrt loss: 0.064657
#               val sqrt loss: 0.106790
#               val xy rmse: 0.127013
#               val z rmse: 0.044130
#               training xy accuracy: 26.25%
#               validation xy accuracy: 30.73%
#               validation z accuracy: 70.83%
#
# [step 000979] avg sqrt loss: 0.079329
#               final sqrt loss: 0.097853
#               val sqrt loss: 0.109284
#               val xy rmse: 0.130387
#               val z rmse: 0.042750
#               training xy accuracy: 26.46%
#               validation xy accuracy: 15.62%
#               validation z accuracy: 70.05%
#
# [step 000989] avg sqrt loss: 0.087397
#               final sqrt loss: 0.075052
#               val sqrt loss: 0.127380
#               val xy rmse: 0.153233
#               val z rmse: 0.041431
#               training xy accuracy: 15.73%
#               validation xy accuracy: 30.73%
#               validation z accuracy: 72.14%
#
# [step 000999] avg sqrt loss: 0.076496
#               final sqrt loss: 0.095610
#               val sqrt loss: 0.136876
#               val xy rmse: 0.165026
#               val z rmse: 0.041688
#               training xy accuracy: 19.27%
#               validation xy accuracy: 17.45%
#               validation z accuracy: 69.79%
#
# Saving model..
# [step 001009] avg sqrt loss: 0.087018
#               final sqrt loss: 0.107829
#               val sqrt loss: 0.118069
#               val xy rmse: 0.141095
#               val z rmse: 0.044779
#               training xy accuracy: 22.92%
#               validation xy accuracy: 16.41%
#               validation z accuracy: 70.31%
#
# [step 001019] avg sqrt loss: 0.066681
#               final sqrt loss: 0.054786
#               val sqrt loss: 0.116383
#               val xy rmse: 0.139391
#               val z rmse: 0.042140
#               training xy accuracy: 22.50%
#               validation xy accuracy: 30.21%
#               validation z accuracy: 71.35%
#
# [step 001029] avg sqrt loss: 0.085954
#               final sqrt loss: 0.101808
#               val sqrt loss: 0.118720
#               val xy rmse: 0.142267
#               val z rmse: 0.042465
#               training xy accuracy: 18.02%
#               validation xy accuracy: 20.05%
#               validation z accuracy: 70.57%
#
# [step 001039] avg sqrt loss: 0.074702
#               final sqrt loss: 0.062322
#               val sqrt loss: 0.120618
#               val xy rmse: 0.144690
#               val z rmse: 0.042137
#               training xy accuracy: 17.50%
#               validation xy accuracy: 8.33%
#               validation z accuracy: 71.61%
#
# [step 001049] avg sqrt loss: 0.088756
#               final sqrt loss: 0.064875
#               val sqrt loss: 0.111408
#               val xy rmse: 0.133066
#               val z rmse: 0.042685
#               training xy accuracy: 6.56%
#               validation xy accuracy: 15.10%
#               validation z accuracy: 71.09%
#
# [step 001059] avg sqrt loss: 0.078605
#               final sqrt loss: 0.055061
#               val sqrt loss: 0.107891
#               val xy rmse: 0.128157
#               val z rmse: 0.045527
#               training xy accuracy: 12.19%
#               validation xy accuracy: 22.66%
#               validation z accuracy: 69.79%
#
# [step 001069] avg sqrt loss: 0.076879
#               final sqrt loss: 0.063276
#               val sqrt loss: 0.106700
#               val xy rmse: 0.127233
#               val z rmse: 0.042168
#               training xy accuracy: 14.06%
#               validation xy accuracy: 11.20%
#               validation z accuracy: 71.09%
#
# [step 001079] avg sqrt loss: 0.094029
#               final sqrt loss: 0.083357
#               val sqrt loss: 0.105618
#               val xy rmse: 0.125719
#               val z rmse: 0.043072
#               training xy accuracy: 20.94%
#               validation xy accuracy: 30.47%
#               validation z accuracy: 70.31%
#
# [step 001089] avg sqrt loss: 0.067281
#               final sqrt loss: 0.076935
#               val sqrt loss: 0.121074
#               val xy rmse: 0.145278
#               val z rmse: 0.042019
#               training xy accuracy: 14.48%
#               validation xy accuracy: 14.06%
#               validation z accuracy: 71.88%
#
# [step 001099] avg sqrt loss: 0.068366
#               final sqrt loss: 0.053508
#               val sqrt loss: 0.104028
#               val xy rmse: 0.123555
#               val z rmse: 0.043976
#               training xy accuracy: 15.31%
#               validation xy accuracy: 22.14%
#               validation z accuracy: 70.05%
#
# Saving model..
# [step 001109] avg sqrt loss: 0.071680
#               final sqrt loss: 0.055382
#               val sqrt loss: 0.108276
#               val xy rmse: 0.128414
#               val z rmse: 0.046808
#               training xy accuracy: 25.83%
#               validation xy accuracy: 31.77%
#               validation z accuracy: 69.01%
#
# [step 001119] avg sqrt loss: 0.074162
#               final sqrt loss: 0.049687
#               val sqrt loss: 0.111045
#               val xy rmse: 0.132590
#               val z rmse: 0.042814
#               training xy accuracy: 23.65%
#               validation xy accuracy: 27.08%
#               validation z accuracy: 71.61%
#
# [step 001129] avg sqrt loss: 0.082907
#               final sqrt loss: 0.135586
#               val sqrt loss: 0.114030
#               val xy rmse: 0.136262
#               val z rmse: 0.043294
#               training xy accuracy: 24.06%
#               validation xy accuracy: 29.69%
#               validation z accuracy: 70.83%
#
# [step 001139] avg sqrt loss: 0.084164
#               final sqrt loss: 0.065494
#               val sqrt loss: 0.112270
#               val xy rmse: 0.133904
#               val z rmse: 0.044195
#               training xy accuracy: 13.65%
#               validation xy accuracy: 4.17%
#               validation z accuracy: 70.83%
#
# [step 001149] avg sqrt loss: 0.089525
#               final sqrt loss: 0.072224
#               val sqrt loss: 0.107355
#               val xy rmse: 0.127582
#               val z rmse: 0.044952
#               training xy accuracy: 21.35%
#               validation xy accuracy: 15.62%
#               validation z accuracy: 70.57%
#
# [step 001159] avg sqrt loss: 0.083146
#               final sqrt loss: 0.098553
#               val sqrt loss: 0.106389
#               val xy rmse: 0.125722
#               val z rmse: 0.048418
#               training xy accuracy: 16.56%
#               validation xy accuracy: 27.86%
#               validation z accuracy: 70.05%
#
# [step 001169] avg sqrt loss: 0.065297
#               final sqrt loss: 0.049856
#               val sqrt loss: 0.119218
#               val xy rmse: 0.142132
#               val z rmse: 0.047283
#               training xy accuracy: 20.62%
#               validation xy accuracy: 24.48%
#               validation z accuracy: 70.31%
#
# [step 001179] avg sqrt loss: 0.076904
#               final sqrt loss: 0.080059
#               val sqrt loss: 0.116049
#               val xy rmse: 0.138325
#               val z rmse: 0.046205
#               training xy accuracy: 16.77%
#               validation xy accuracy: 31.51%
#               validation z accuracy: 70.57%
#
# [step 001189] avg sqrt loss: 0.094283
#               final sqrt loss: 0.155190
#               val sqrt loss: 0.108303
#               val xy rmse: 0.128195
#               val z rmse: 0.048172
#               training xy accuracy: 19.38%
#               validation xy accuracy: 16.15%
#               validation z accuracy: 70.31%
#
# [step 001199] avg sqrt loss: 0.081178
#               final sqrt loss: 0.112899
#               val sqrt loss: 0.111600
#               val xy rmse: 0.132908
#               val z rmse: 0.045111
#               training xy accuracy: 6.67%
#               validation xy accuracy: 11.20%
#               validation z accuracy: 71.09%
#
# Saving model..
# [step 001209] avg sqrt loss: 0.081630
#               final sqrt loss: 0.099178
#               val sqrt loss: 0.116889
#               val xy rmse: 0.139325
#               val z rmse: 0.046543
#               training xy accuracy: 11.67%
#               validation xy accuracy: 0.52%
#               validation z accuracy: 70.31%
#
# [step 001219] avg sqrt loss: 0.078269
#               final sqrt loss: 0.079191
#               val sqrt loss: 0.114134
#               val xy rmse: 0.136066
#               val z rmse: 0.045294
#               training xy accuracy: 8.33%
#               validation xy accuracy: 5.73%
#               validation z accuracy: 70.83%
#
# [step 001229] avg sqrt loss: 0.079540
#               final sqrt loss: 0.041763
#               val sqrt loss: 0.109168
#               val xy rmse: 0.129691
#               val z rmse: 0.045970
#               training xy accuracy: 17.81%
#               validation xy accuracy: 21.09%
#               validation z accuracy: 70.57%
#
# [step 001239] avg sqrt loss: 0.070650
#               final sqrt loss: 0.104788
#               val sqrt loss: 0.102591
#               val xy rmse: 0.121733
#               val z rmse: 0.044008
#               training xy accuracy: 21.15%
#               validation xy accuracy: 23.44%
#               validation z accuracy: 71.09%
#
# [step 001249] avg sqrt loss: 0.066062
#               final sqrt loss: 0.069381
#               val sqrt loss: 0.101899
#               val xy rmse: 0.119916
#               val z rmse: 0.048895
#               training xy accuracy: 13.12%
#               validation xy accuracy: 41.15%
#               validation z accuracy: 69.79%
#
# [step 001259] avg sqrt loss: 0.074559
#               final sqrt loss: 0.085835
#               val sqrt loss: 0.110823
#               val xy rmse: 0.132037
#               val z rmse: 0.044476
#               training xy accuracy: 22.08%
#               validation xy accuracy: 22.66%
#               validation z accuracy: 70.05%
#
# [step 001269] avg sqrt loss: 0.068448
#               final sqrt loss: 0.080397
#               val sqrt loss: 0.108257
#               val xy rmse: 0.128803
#               val z rmse: 0.044475
#               training xy accuracy: 18.02%
#               validation xy accuracy: 35.94%
#               validation z accuracy: 69.53%
#
# [step 001279] avg sqrt loss: 0.069690
#               final sqrt loss: 0.058406
#               val sqrt loss: 0.105333
#               val xy rmse: 0.124820
#               val z rmse: 0.046096
#               training xy accuracy: 24.79%
#               validation xy accuracy: 25.00%
#               validation z accuracy: 70.83%
#
# [step 001289] avg sqrt loss: 0.067000
#               final sqrt loss: 0.098449
#               val sqrt loss: 0.105876
#               val xy rmse: 0.125255
#               val z rmse: 0.047446
#               training xy accuracy: 24.38%
#               validation xy accuracy: 35.94%
#               validation z accuracy: 70.05%
#
# [step 001299] avg sqrt loss: 0.088640
#               final sqrt loss: 0.104933
#               val sqrt loss: 0.107979
#               val xy rmse: 0.128640
#               val z rmse: 0.043382
#               training xy accuracy: 19.06%
#               validation xy accuracy: 37.76%
#               validation z accuracy: 70.57%
#
# Saving model..
# [step 001309] avg sqrt loss: 0.058608
#               final sqrt loss: 0.063050
#               val sqrt loss: 0.112960
#               val xy rmse: 0.134611
#               val z rmse: 0.045166
#               training xy accuracy: 23.75%
#               validation xy accuracy: 28.39%
#               validation z accuracy: 70.31%
#
# [step 001319] avg sqrt loss: 0.090332
#               final sqrt loss: 0.119106
#               val sqrt loss: 0.120279
#               val xy rmse: 0.143939
#               val z rmse: 0.044317
#               training xy accuracy: 16.98%
#               validation xy accuracy: 13.80%
#               validation z accuracy: 70.57%
#
# [step 001329] avg sqrt loss: 0.074337
#               final sqrt loss: 0.033056
#               val sqrt loss: 0.117449
#               val xy rmse: 0.140010
#               val z rmse: 0.046662
#               training xy accuracy: 9.48%
#               validation xy accuracy: 13.02%
#               validation z accuracy: 70.83%
#
# [step 001339] avg sqrt loss: 0.076095
#               final sqrt loss: 0.063767
#               val sqrt loss: 0.112969
#               val xy rmse: 0.134266
#               val z rmse: 0.047234
#               training xy accuracy: 16.56%
#               validation xy accuracy: 31.51%
#               validation z accuracy: 70.83%
#
# [step 001349] avg sqrt loss: 0.069481
#               final sqrt loss: 0.036471
#               val sqrt loss: 0.109407
#               val xy rmse: 0.130538
#               val z rmse: 0.042771
#               training xy accuracy: 16.67%
#               validation xy accuracy: 11.72%
#               validation z accuracy: 71.61%
#
# [step 001359] avg sqrt loss: 0.082034
#               final sqrt loss: 0.048010
#               val sqrt loss: 0.108811
#               val xy rmse: 0.129652
#               val z rmse: 0.043593
#               training xy accuracy: 13.85%
#               validation xy accuracy: 18.49%
#               validation z accuracy: 71.35%
#
# [step 001369] avg sqrt loss: 0.051915
#               final sqrt loss: 0.041463
#               val sqrt loss: 0.108506
#               val xy rmse: 0.129319
#               val z rmse: 0.043286
#               training xy accuracy: 17.50%
#               validation xy accuracy: 22.92%
#               validation z accuracy: 71.09%
#
# [step 001379] avg sqrt loss: 0.052576
#               final sqrt loss: 0.055210
#               val sqrt loss: 0.103807
#               val xy rmse: 0.123022
#               val z rmse: 0.045376
#               training xy accuracy: 21.88%
#               validation xy accuracy: 8.33%
#               validation z accuracy: 70.31%
#
# [step 001389] avg sqrt loss: 0.076885
#               final sqrt loss: 0.133610
#               val sqrt loss: 0.108486
#               val xy rmse: 0.129385
#               val z rmse: 0.042740
#               training xy accuracy: 22.50%
#               validation xy accuracy: 26.30%
#               validation z accuracy: 71.61%
#
# [step 001399] avg sqrt loss: 0.083927
#               final sqrt loss: 0.116004
#               val sqrt loss: 0.108421
#               val xy rmse: 0.129229
#               val z rmse: 0.043185
#               training xy accuracy: 18.44%
#               validation xy accuracy: 9.64%
#               validation z accuracy: 70.05%
#
# Saving model..
# [step 001409] avg sqrt loss: 0.085294
#               final sqrt loss: 0.072732
#               val sqrt loss: 0.107061
#               val xy rmse: 0.127620
#               val z rmse: 0.042576
#               training xy accuracy: 8.23%
#               validation xy accuracy: 2.34%
#               validation z accuracy: 71.09%
#
# [step 001419] avg sqrt loss: 0.068052
#               final sqrt loss: 0.086371
#               val sqrt loss: 0.105342
#               val xy rmse: 0.125284
#               val z rmse: 0.043574
#               training xy accuracy: 17.50%
#               validation xy accuracy: 24.74%
#               validation z accuracy: 71.09%
#
# [step 001429] avg sqrt loss: 0.084682
#               final sqrt loss: 0.042572
#               val sqrt loss: 0.103733
#               val xy rmse: 0.123168
#               val z rmse: 0.044059
#               training xy accuracy: 23.75%
#               validation xy accuracy: 25.52%
#               validation z accuracy: 71.35%
#
# [step 001439] avg sqrt loss: 0.080568
#               final sqrt loss: 0.088519
#               val sqrt loss: 0.103703
#               val xy rmse: 0.122576
#               val z rmse: 0.047041
#               training xy accuracy: 23.02%
#               validation xy accuracy: 13.54%
#               validation z accuracy: 70.57%
#
# [step 001449] avg sqrt loss: 0.081649
#               final sqrt loss: 0.072077
#               val sqrt loss: 0.103621
#               val xy rmse: 0.122784
#               val z rmse: 0.045386
#               training xy accuracy: 17.50%
#               validation xy accuracy: 33.59%
#               validation z accuracy: 70.57%
#
# [step 001459] avg sqrt loss: 0.073023
#               final sqrt loss: 0.063066
#               val sqrt loss: 0.103259
#               val xy rmse: 0.122337
#               val z rmse: 0.045325
#               training xy accuracy: 25.10%
#               validation xy accuracy: 40.36%
#               validation z accuracy: 70.57%
#
# [step 001469] avg sqrt loss: 0.082701
#               final sqrt loss: 0.020240
#               val sqrt loss: 0.108040
#               val xy rmse: 0.128470
#               val z rmse: 0.044822
#               training xy accuracy: 26.46%
#               validation xy accuracy: 21.61%
#               validation z accuracy: 70.57%
#
# [step 001479] avg sqrt loss: 0.065059
#               final sqrt loss: 0.069107
#               val sqrt loss: 0.112123
#               val xy rmse: 0.134117
#               val z rmse: 0.041713
#               training xy accuracy: 27.08%
#               validation xy accuracy: 26.04%
#               validation z accuracy: 70.83%
#
# [step 001489] avg sqrt loss: 0.063384
#               final sqrt loss: 0.085656
#               val sqrt loss: 0.126467
#               val xy rmse: 0.151348
#               val z rmse: 0.046573
#               training xy accuracy: 23.65%
#               validation xy accuracy: 25.26%
#               validation z accuracy: 68.49%
#
# [step 001499] avg sqrt loss: 0.088709
#               final sqrt loss: 0.075095
#               val sqrt loss: 0.109846
#               val xy rmse: 0.130700
#               val z rmse: 0.045099
# ...
#               val xy rmse: 0.133384
#               val z rmse: 0.037816
#               training xy accuracy: 69.48%
#               validation xy accuracy: 67.97%
#               validation z accuracy: 71.88%
#
# [step 021539] avg sqrt loss: 0.052166
#               final sqrt loss: 0.032969
#               val sqrt loss: 0.111087
#               val xy rmse: 0.133362
#               val z rmse: 0.038081
#               training xy accuracy: 68.54%
#               validation xy accuracy: 73.18%
#               validation z accuracy: 72.40%
#
# [step 021549] avg sqrt loss: 0.044367
#               final sqrt loss: 0.037790
#               val sqrt loss: 0.110858
#               val xy rmse: 0.133150
#               val z rmse: 0.037556
#               training xy accuracy: 74.58%
#               validation xy accuracy: 77.60%
#               validation z accuracy: 71.88%
#
# [step 021559] avg sqrt loss: 0.051536
#               final sqrt loss: 0.032365
#               val sqrt loss: 0.110139
#               val xy rmse: 0.132306
#               val z rmse: 0.037174
#               training xy accuracy: 74.27%
#               validation xy accuracy: 77.60%
#               validation z accuracy: 72.40%
#
# [step 021569] avg sqrt loss: 0.062850
#               final sqrt loss: 0.104972
#               val sqrt loss: 0.110908
#               val xy rmse: 0.133110
#               val z rmse: 0.038274
#               training xy accuracy: 72.50%
#               validation xy accuracy: 50.78%
#               validation z accuracy: 72.40%
#
# [step 021579] avg sqrt loss: 0.047108
#               final sqrt loss: 0.022343
#               val sqrt loss: 0.106978
#               val xy rmse: 0.128277
#               val z rmse: 0.037728
#               training xy accuracy: 63.12%
#               validation xy accuracy: 80.21%
#               validation z accuracy: 70.83%
#
# [step 021589] avg sqrt loss: 0.056963
#               final sqrt loss: 0.032610
#               val sqrt loss: 0.106853
#               val xy rmse: 0.128352
#               val z rmse: 0.036111
#               training xy accuracy: 71.04%
#               validation xy accuracy: 54.69%
#               validation z accuracy: 72.14%
#
# [step 021599] avg sqrt loss: 0.040942
#               final sqrt loss: 0.052649
#               val sqrt loss: 0.109554
#               val xy rmse: 0.131848
#               val z rmse: 0.035193
#               training xy accuracy: 71.25%
#               validation xy accuracy: 80.73%
#               validation z accuracy: 71.88%
#
# Saving model..
# [step 021609] avg sqrt loss: 0.070368
#               final sqrt loss: 0.050504
#               val sqrt loss: 0.116945
#               val xy rmse: 0.140930
#               val z rmse: 0.036131
#               training xy accuracy: 73.23%
#               validation xy accuracy: 73.96%
#               validation z accuracy: 71.09%
#
# [step 021619] avg sqrt loss: 0.053174
#               final sqrt loss: 0.063519
#               val sqrt loss: 0.117040
#               val xy rmse: 0.141103
#               val z rmse: 0.035702
#               training xy accuracy: 71.56%
#               validation xy accuracy: 65.10%
#               validation z accuracy: 71.88%
#
# [step 021629] avg sqrt loss: 0.037681
#               final sqrt loss: 0.014187
#               val sqrt loss: 0.116327
#               val xy rmse: 0.140300
#               val z rmse: 0.035042
#               training xy accuracy: 72.08%
#               validation xy accuracy: 77.34%
#               validation z accuracy: 72.40%
#
# [step 021639] avg sqrt loss: 0.077203
#               final sqrt loss: 0.039560
#               val sqrt loss: 0.112005
#               val xy rmse: 0.135066
#               val z rmse: 0.033906
#               training xy accuracy: 58.33%
#               validation xy accuracy: 42.71%
#               validation z accuracy: 72.40%
#
# [step 021649] avg sqrt loss: 0.057420
#               final sqrt loss: 0.049386
#               val sqrt loss: 0.109841
#               val xy rmse: 0.132352
#               val z rmse: 0.034067
#               training xy accuracy: 62.60%
#               validation xy accuracy: 75.00%
#               validation z accuracy: 72.14%
#
# [step 021659] avg sqrt loss: 0.058210
#               final sqrt loss: 0.075603
#               val sqrt loss: 0.105591
#               val xy rmse: 0.126619
#               val z rmse: 0.037192
#               training xy accuracy: 71.25%
#               validation xy accuracy: 71.35%
#               validation z accuracy: 71.88%
#
# [step 021669] avg sqrt loss: 0.033760
#               final sqrt loss: 0.095656
#               val sqrt loss: 0.103386
#               val xy rmse: 0.123828
#               val z rmse: 0.037404
#               training xy accuracy: 76.67%
#               validation xy accuracy: 74.74%
#               validation z accuracy: 72.14%
#
# [step 021679] avg sqrt loss: 0.061608
#               final sqrt loss: 0.055819
#               val sqrt loss: 0.102747
#               val xy rmse: 0.123042
#               val z rmse: 0.037310
#               training xy accuracy: 64.27%
#               validation xy accuracy: 71.61%
#               validation z accuracy: 71.61%
#
# [step 021689] avg sqrt loss: 0.047064
#               final sqrt loss: 0.028109
#               val sqrt loss: 0.103056
#               val xy rmse: 0.123454
#               val z rmse: 0.037147
#               training xy accuracy: 70.83%
#               validation xy accuracy: 77.34%
#               validation z accuracy: 71.61%
#
# [step 021699] avg sqrt loss: 0.043247
#               final sqrt loss: 0.085300
#               val sqrt loss: 0.101490
#               val xy rmse: 0.121404
#               val z rmse: 0.037725
#               training xy accuracy: 71.77%
#               validation xy accuracy: 64.58%
#               validation z accuracy: 72.14%
#
# Saving model..
# [step 021709] avg sqrt loss: 0.057172
#               final sqrt loss: 0.092284
#               val sqrt loss: 0.099993
#               val xy rmse: 0.119369
#               val z rmse: 0.038704
#               training xy accuracy: 68.85%
#               validation xy accuracy: 74.22%
#               validation z accuracy: 71.88%
#
# [step 021719] avg sqrt loss: 0.049671
#               final sqrt loss: 0.016161
#               val sqrt loss: 0.096405
#               val xy rmse: 0.114600
#               val z rmse: 0.040191
#               training xy accuracy: 72.60%
#               validation xy accuracy: 76.04%
#               validation z accuracy: 71.35%
#
# [step 021729] avg sqrt loss: 0.040485
#               final sqrt loss: 0.062517
#               val sqrt loss: 0.094200
#               val xy rmse: 0.111736
#               val z rmse: 0.040633
#               training xy accuracy: 75.10%
#               validation xy accuracy: 83.33%
#               validation z accuracy: 71.09%
#
# [step 021739] avg sqrt loss: 0.070646
#               final sqrt loss: 0.093830
#               val sqrt loss: 0.093909
#               val xy rmse: 0.111339
#               val z rmse: 0.040791
#               training xy accuracy: 71.77%
#               validation xy accuracy: 68.75%
#               validation z accuracy: 71.09%
#
# [step 021749] avg sqrt loss: 0.045609
#               final sqrt loss: 0.030220
#               val sqrt loss: 0.094894
#               val xy rmse: 0.112395
#               val z rmse: 0.041823
#               training xy accuracy: 72.40%
#               validation xy accuracy: 77.60%
#               validation z accuracy: 71.09%
#
# [step 021759] avg sqrt loss: 0.060551
#               final sqrt loss: 0.042278
#               val sqrt loss: 0.097388
#               val xy rmse: 0.115648
#               val z rmse: 0.041282
#               training xy accuracy: 74.58%
#               validation xy accuracy: 79.95%
#               validation z accuracy: 70.83%
#
# [step 021769] avg sqrt loss: 0.058531
#               final sqrt loss: 0.102417
#               val sqrt loss: 0.099970
#               val xy rmse: 0.118831
#               val z rmse: 0.041719
#               training xy accuracy: 78.44%
#               validation xy accuracy: 77.86%
#               validation z accuracy: 70.57%
#
# [step 021779] avg sqrt loss: 0.045889
#               final sqrt loss: 0.035162
#               val sqrt loss: 0.103575
#               val xy rmse: 0.123351
#               val z rmse: 0.041858
#               training xy accuracy: 73.12%
#               validation xy accuracy: 75.52%
#               validation z accuracy: 71.09%
#
# [step 021789] avg sqrt loss: 0.047266
#               final sqrt loss: 0.052350
#               val sqrt loss: 0.105622
#               val xy rmse: 0.126023
#               val z rmse: 0.041282
#               training xy accuracy: 70.00%
#               validation xy accuracy: 82.03%
#               validation z accuracy: 71.61%
#
# [step 021799] avg sqrt loss: 0.043025
#               final sqrt loss: 0.050774
#               val sqrt loss: 0.109781
#               val xy rmse: 0.131343
#               val z rmse: 0.040664
#               training xy accuracy: 73.85%
#               validation xy accuracy: 83.59%
#               validation z accuracy: 71.09%
#
# Saving model..
# [step 021809] avg sqrt loss: 0.051803
#               final sqrt loss: 0.013891
#               val sqrt loss: 0.109276
#               val xy rmse: 0.131067
#               val z rmse: 0.038294
#               training xy accuracy: 76.77%
#               validation xy accuracy: 71.35%
#               validation z accuracy: 72.14%
#
# [step 021819] avg sqrt loss: 0.067041
#               final sqrt loss: 0.018990
#               val sqrt loss: 0.106837
#               val xy rmse: 0.128063
#               val z rmse: 0.037972
#               training xy accuracy: 62.19%
#               validation xy accuracy: 75.00%
#               validation z accuracy: 71.88%
#
# [step 021829] avg sqrt loss: 0.047995
#               final sqrt loss: 0.076315
#               val sqrt loss: 0.106548
#               val xy rmse: 0.127752
#               val z rmse: 0.037634
#               training xy accuracy: 67.08%
#               validation xy accuracy: 71.61%
#               validation z accuracy: 71.88%
#
# [step 021839] avg sqrt loss: 0.049031
#               final sqrt loss: 0.021507
#               val sqrt loss: 0.107926
#               val xy rmse: 0.129546
#               val z rmse: 0.037146
#               training xy accuracy: 68.23%
#               validation xy accuracy: 69.79%
#               validation z accuracy: 71.35%
#
# [step 021849] avg sqrt loss: 0.045522
#               final sqrt loss: 0.022091
#               val sqrt loss: 0.107729
#               val xy rmse: 0.129428
#               val z rmse: 0.036239
#               training xy accuracy: 69.79%
#               validation xy accuracy: 76.04%
#               validation z accuracy: 72.40%
#
# [step 021859] avg sqrt loss: 0.055154
#               final sqrt loss: 0.075575
#               val sqrt loss: 0.103100
#               val xy rmse: 0.123614
#               val z rmse: 0.036438
#               training xy accuracy: 66.88%
#               validation xy accuracy: 71.61%
#               validation z accuracy: 72.14%
#
# [step 021869] avg sqrt loss: 0.052954
#               final sqrt loss: 0.020132
#               val sqrt loss: 0.111259
#               val xy rmse: 0.133894
#               val z rmse: 0.035785
#               training xy accuracy: 56.46%
#               validation xy accuracy: 54.69%
#               validation z accuracy: 71.88%
#
# [step 021879] avg sqrt loss: 0.062617
#               final sqrt loss: 0.074819
#               val sqrt loss: 0.114282
#               val xy rmse: 0.137581
#               val z rmse: 0.036391
#               training xy accuracy: 49.17%
#               validation xy accuracy: 68.75%
#               validation z accuracy: 72.14%
#
# [step 021889] avg sqrt loss: 0.050306
#               final sqrt loss: 0.066639
#               val sqrt loss: 0.119974
#               val xy rmse: 0.144865
#               val z rmse: 0.034783
#               training xy accuracy: 52.71%
#               validation xy accuracy: 67.19%
#               validation z accuracy: 71.88%
#
# [step 021899] avg sqrt loss: 0.058458
#               final sqrt loss: 0.028060
#               val sqrt loss: 0.113416
#               val xy rmse: 0.136822
#               val z rmse: 0.033892
#               training xy accuracy: 59.17%
#               validation xy accuracy: 71.61%
#               validation z accuracy: 71.88%
#
# Saving model..
# [step 021909] avg sqrt loss: 0.077304
#               final sqrt loss: 0.096359
#               val sqrt loss: 0.109354
#               val xy rmse: 0.131715
#               val z rmse: 0.034307
#               training xy accuracy: 66.15%
#               validation xy accuracy: 57.55%
#               validation z accuracy: 71.88%
#
# [step 021919] avg sqrt loss: 0.037959
#               final sqrt loss: 0.013759
#               val sqrt loss: 0.108528
#               val xy rmse: 0.130508
#               val z rmse: 0.035639
#               training xy accuracy: 53.75%
#               validation xy accuracy: 76.56%
#               validation z accuracy: 71.88%
#
# [step 021929] avg sqrt loss: 0.044614
#               final sqrt loss: 0.039648
#               val sqrt loss: 0.110598
#               val xy rmse: 0.133103
#               val z rmse: 0.035535
#               training xy accuracy: 70.94%
#               validation xy accuracy: 73.18%
#               validation z accuracy: 71.88%
#
# [step 021939] avg sqrt loss: 0.047462
#               final sqrt loss: 0.030029
#               val sqrt loss: 0.110752
#               val xy rmse: 0.133156
#               val z rmse: 0.036562
#               training xy accuracy: 75.42%
#               validation xy accuracy: 77.34%
#               validation z accuracy: 71.88%
#
# [step 021949] avg sqrt loss: 0.058740
#               final sqrt loss: 0.025734
#               val sqrt loss: 0.114478
#               val xy rmse: 0.137807
#               val z rmse: 0.036527
#               training xy accuracy: 70.94%
#               validation xy accuracy: 72.66%
#               validation z accuracy: 71.09%
#
# [step 021959] avg sqrt loss: 0.053184
#               final sqrt loss: 0.082146
#               val sqrt loss: 0.115796
#               val xy rmse: 0.139546
#               val z rmse: 0.035780
#               training xy accuracy: 69.27%
#               validation xy accuracy: 59.64%
#               validation z accuracy: 71.88%
#
# [step 021969] avg sqrt loss: 0.060148
#               final sqrt loss: 0.096605
#               val sqrt loss: 0.109901
#               val xy rmse: 0.132277
#               val z rmse: 0.035214
#               training xy accuracy: 66.77%
#               validation xy accuracy: 70.31%
#               validation z accuracy: 72.40%
#
# [step 021979] avg sqrt loss: 0.074767
#               final sqrt loss: 0.064422
#               val sqrt loss: 0.108480
#               val xy rmse: 0.130454
#               val z rmse: 0.035600
#               training xy accuracy: 60.21%
#               validation xy accuracy: 65.89%
#               validation z accuracy: 72.14%
#
# [step 021989] avg sqrt loss: 0.056566
#               final sqrt loss: 0.063831
#               val sqrt loss: 0.107586
#               val xy rmse: 0.129278
#               val z rmse: 0.036041
#               training xy accuracy: 52.92%
#               validation xy accuracy: 59.38%
#               validation z accuracy: 72.14%
#
# [step 021999] avg sqrt loss: 0.050309
#               final sqrt loss: 0.052319
#               val sqrt loss: 0.104210
#               val xy rmse: 0.125034
#               val z rmse: 0.036224
#               training xy accuracy: 63.96%
#               validation xy accuracy: 66.67%
#               validation z accuracy: 71.35%
#
# Saving model..
# [step 022009] avg sqrt loss: 0.050694
#               final sqrt loss: 0.022103
#               val sqrt loss: 0.099121
#               val xy rmse: 0.118643
#               val z rmse: 0.036367
#               training xy accuracy: 61.15%
#               validation xy accuracy: 73.44%
#               validation z accuracy: 71.88%
#
# [step 022019] avg sqrt loss: 0.062088
#               final sqrt loss: 0.061755
#               val sqrt loss: 0.097971
#               val xy rmse: 0.117090
#               val z rmse: 0.037076
#               training xy accuracy: 65.62%
#               validation xy accuracy: 67.71%
#               validation z accuracy: 71.09%
#
# Interrupted, saving..
# Finished Training

# %%
shape = (10, 5)
fig, ax = plt.subplots(shape[0], shape[1], figsize=(shape[1]*3, shape[0]*3))

image, pip_pos = training_data[:shape[0]*shape[1]].get_arrays()
inds = np.arange(len(image))
np.random.shuffle(inds)
image = image[inds]
pip_pos = pip_pos[inds]

# pip_pos = training_data.output_norm.denormalize(pip_pos)
# use model in inference mode to make prediction from image
model.eval()
with torch.no_grad():
    image_tensor = make_image_tensor(image)
    pred = model(image_tensor).cpu().numpy()
    pred = pos_normalizer.denormalize(pred)


for i, axi in enumerate(ax.flatten()):
    # pred = training_data.output_norm.denormalize(model.model.predict(image))
    axi.imshow(image[i], cmap='gray')
    axi.scatter(pip_pos[i, 2], pip_pos[i, 1], color='red', s=12)
    axi.scatter(pred[i, 2], pred[i, 1], color=(0.1, 1.0, 0.1), s=10)
